# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import DenseNet201
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# PARAMETERS
train_dir = r'C:\Users\kashi\Desktop\LY Project\Multi Cancer\Robust\Robust_Data'  # Dataset path
img_height, img_width = 224, 224  # DenseNet201 input size
batch_size = 32
num_classes = 16  # Update if number of classes differs
epochs = 10

# LOAD DATA - RESCALE AND SPLIT
print("Loading training data without augmentation (only rescaling)...")

datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2  # 20% validation split
)

train_generator = datagen.flow_from_directory(
    train_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical',
    subset='training',
    shuffle=True
)

validation_generator = datagen.flow_from_directory(
    train_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation',
    shuffle=False
)

# LOAD DenseNet201 BASE MODEL AND FREEZE LAYERS
print("Loading DenseNet201 pre-trained base model...")
base_model = DenseNet201(weights='imagenet', include_top=False, input_shape=(img_height, img_width, 3))

for layer in base_model.layers:
    layer.trainable = False
print(f"Frozen {len(base_model.layers)} layers of DenseNet201 base.")

# ADD CUSTOM CLASSIFIER ON TOP
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.5)(x)
predictions = Dense(num_classes, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=predictions)

# COMPILE MODEL
print("Compiling model...")
model.compile(
    optimizer=Adam(learning_rate=0.0001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# TRAIN MODEL WITH CHECKPOINT
checkpoint_filepath = 'best_densenet201_cancer_model.h5'
checkpoint = tf.keras.callbacks.ModelCheckpoint(
    checkpoint_filepath, monitor='val_accuracy', save_best_only=True, verbose=1
)

print(f"Training for {epochs} epochs...")
history = model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=epochs,
    callbacks=[checkpoint]
)

print("Training completed.")
print(f"Best model saved at {checkpoint_filepath}")

# LOAD BEST MODEL FROM CHECKPOINT
print("Loading best model for evaluation...")
model.load_weights(checkpoint_filepath)

# PREDICTIONS AND CONFUSION MATRIX
print("Predicting classes on validation data...")
val_steps = validation_generator.samples // validation_generator.batch_size + 1

y_pred_probs = model.predict(validation_generator, steps=val_steps)
y_pred = np.argmax(y_pred_probs, axis=1)

y_true = validation_generator.classes
class_labels = list(validation_generator.class_indices.keys())

cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()

print("Classification Report:")
print(classification_report(y_true, y_pred, target_names=class_labels))
# Out:
# Loading training data without augmentation (only rescaling)...
# Found 64002 images belonging to 16 classes.
# Found 16000 images belonging to 16 classes.
# Loading DenseNet201 pre-trained base model...
# Frozen 707 layers of DenseNet201 base.
# Compiling model...
# Training for 10 epochs...
# C:\Users\kashi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 0s 839ms/step - accuracy: 0.6760 - loss: 0.9880
# Epoch 1: val_accuracy improved from -inf to 0.90462, saving model to best_densenet201_cancer_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 2118s 1s/step - accuracy: 0.6761 - loss: 0.9878 - val_accuracy: 0.9046 - val_loss: 0.2551
# Epoch 2/10
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 0s 815ms/step - accuracy: 0.8888 - loss: 0.2903
# Epoch 2: val_accuracy improved from 0.90462 to 0.92962, saving model to best_densenet201_cancer_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 2037s 1s/step - accuracy: 0.8888 - loss: 0.2903 - val_accuracy: 0.9296 - val_loss: 0.1894
# Epoch 3/10
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 0s 814ms/step - accuracy: 0.9205 - loss: 0.2137
# Epoch 3: val_accuracy improved from 0.92962 to 0.94406, saving model to best_densenet201_cancer_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 2034s 1s/step - accuracy: 0.9205 - loss: 0.2137 - val_accuracy: 0.9441 - val_loss: 0.1552
# Epoch 4/10
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 0s 849ms/step - accuracy: 0.9360 - loss: 0.1730
# Epoch 4: val_accuracy improved from 0.94406 to 0.95200, saving model to best_densenet201_cancer_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 2111s 1s/step - accuracy: 0.9360 - loss: 0.1730 - val_accuracy: 0.9520 - val_loss: 0.1338
# Epoch 5/10
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 0s 785ms/step - accuracy: 0.9446 - loss: 0.1507
# Epoch 5: val_accuracy improved from 0.95200 to 0.95769, saving model to best_densenet201_cancer_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 1969s 984ms/step - accuracy: 0.9446 - loss: 0.1507 - val_accuracy: 0.9577 - val_loss: 0.1206
# Epoch 6/10
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 0s 797ms/step - accuracy: 0.9542 - loss: 0.1262
# Epoch 6: val_accuracy improved from 0.95769 to 0.96031, saving model to best_densenet201_cancer_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 1988s 994ms/step - accuracy: 0.9542 - loss: 0.1262 - val_accuracy: 0.9603 - val_loss: 0.1067
# Epoch 7/10
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 0s 804ms/step - accuracy: 0.9584 - loss: 0.1142
# Epoch 7: val_accuracy improved from 0.96031 to 0.96531, saving model to best_densenet201_cancer_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 2011s 1s/step - accuracy: 0.9584 - loss: 0.1142 - val_accuracy: 0.9653 - val_loss: 0.0960
# Epoch 8/10
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 0s 806ms/step - accuracy: 0.9620 - loss: 0.1044
# Epoch 8: val_accuracy improved from 0.96531 to 0.96700, saving model to best_densenet201_cancer_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 2015s 1s/step - accuracy: 0.9620 - loss: 0.1044 - val_accuracy: 0.9670 - val_loss: 0.0909
# Epoch 9/10
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 0s 802ms/step - accuracy: 0.9683 - loss: 0.0912
# Epoch 9: val_accuracy improved from 0.96700 to 0.96956, saving model to best_densenet201_cancer_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 2007s 1s/step - accuracy: 0.9683 - loss: 0.0912 - val_accuracy: 0.9696 - val_loss: 0.0830
# Epoch 10/10
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 0s 807ms/step - accuracy: 0.9710 - loss: 0.0838
# Epoch 10: val_accuracy improved from 0.96956 to 0.97069, saving model to best_densenet201_cancer_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 2016s 1s/step - accuracy: 0.9710 - loss: 0.0838 - val_accuracy: 0.9707 - val_loss: 0.0790
# Training completed.
# Best model saved at best_densenet201_cancer_model.h5
# Loading best model for evaluation...
# Predicting classes on validation data...
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 395s 783ms/step
# C:\Users\kashi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\trainers\epoch_iterator.py:116: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# Classification Report:
#                   precision    recall  f1-score   support
#
#       all_benign       1.00      1.00      1.00      1000
#        all_early       1.00      1.00      1.00      1000
#          all_pre       1.00      1.00      1.00      1000
#          all_pro       1.00      1.00      1.00      1000
#    breast_benign       0.98      0.98      0.98      1000
# breast_malignant       0.98      0.98      0.98      1000
#        colon_aca       1.00      1.00      1.00      1000
#        colon_bnt       1.00      1.00      1.00      1000
#         lung_aca       0.98      0.99      0.98      1000
#         lung_bnt       1.00      1.00      1.00      1000
#         lung_scc       0.99      0.98      0.98      1000
#        lymph_cll       0.89      0.98      0.93      1000
#         lymph_fl       0.95      0.96      0.96      1000
#        lymph_mcl       0.98      0.87      0.92      1000
#      oral_normal       0.90      0.91      0.90      1000
#         oral_scc       0.90      0.90      0.90      1000
#
#         accuracy                           0.97     16000
#        macro avg       0.97      0.97      0.97     16000
#     weighted avg       0.97      0.97      0.97     16000
