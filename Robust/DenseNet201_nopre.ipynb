# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import DenseNet201
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# PARAMETERS
train_dir = r'C:\Users\kashi\Desktop\LY Project\Multi Cancer\Robust\Robust_Data'  # Dataset path
img_height, img_width = 224, 224  # DenseNet201 input size
batch_size = 32
num_classes = 16  # Update if number of classes differs
epochs = 10

# LOAD DATA - RESCALE AND SPLIT
print("Loading training data without augmentation (only rescaling)...")

datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2  # 20% validation split
)

train_generator = datagen.flow_from_directory(
    train_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical',
    subset='training',
    shuffle=True
)

validation_generator = datagen.flow_from_directory(
    train_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation',
    shuffle=False
)

# LOAD DenseNet201 BASE MODEL AND FREEZE LAYERS
print("Loading DenseNet201 pre-trained base model...")
base_model = DenseNet201(weights='imagenet', include_top=False, input_shape=(img_height, img_width, 3))

for layer in base_model.layers:
    layer.trainable = False
print(f"Frozen {len(base_model.layers)} layers of DenseNet201 base.")

# ADD CUSTOM CLASSIFIER ON TOP
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.5)(x)
predictions = Dense(num_classes, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=predictions)

# COMPILE MODEL
print("Compiling model...")
model.compile(
    optimizer=Adam(learning_rate=0.0001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# TRAIN MODEL WITH CHECKPOINT
checkpoint_filepath = 'best_densenet201_cancer_model.h5'
checkpoint = tf.keras.callbacks.ModelCheckpoint(
    checkpoint_filepath, monitor='val_accuracy', save_best_only=True, verbose=1
)

print(f"Training for {epochs} epochs...")
history = model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=epochs,
    callbacks=[checkpoint]
)

print("Training completed.")
print(f"Best model saved at {checkpoint_filepath}")

# LOAD BEST MODEL FROM CHECKPOINT
print("Loading best model for evaluation...")
model.load_weights(checkpoint_filepath)

# PREDICTIONS AND CONFUSION MATRIX
print("Predicting classes on validation data...")
val_steps = validation_generator.samples // validation_generator.batch_size + 1

y_pred_probs = model.predict(validation_generator, steps=val_steps)
y_pred = np.argmax(y_pred_probs, axis=1)

y_true = validation_generator.classes
class_labels = list(validation_generator.class_indices.keys())

cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()

print("Classification Report:")
print(classification_report(y_true, y_pred, target_names=class_labels))
# Out:
# Loading training data without augmentation (only rescaling)...
# Found 64002 images belonging to 16 classes.
# Found 16000 images belonging to 16 classes.
# Loading DenseNet201 pre-trained base model...
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5
# 74836368/74836368 ━━━━━━━━━━━━━━━━━━━━ 8s 0us/step
# Frozen 707 layers of DenseNet201 base.
# Compiling model...
# Training for 20 epochs...
# C:\Users\kashi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/20
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 0s 821ms/step - accuracy: 0.6666 - loss: 1.0162
# Epoch 1: val_accuracy improved from -inf to 0.90763, saving model to best_densenet201_cancer_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 2074s 1s/step - accuracy: 0.6667 - loss: 1.0160 - val_accuracy: 0.9076 - val_loss: 0.2562
# Epoch 2/20
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 0s 806ms/step - accuracy: 0.8866 - loss: 0.2946
# Epoch 2: val_accuracy improved from 0.90763 to 0.93106, saving model to best_densenet201_cancer_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 2010s 1s/step - accuracy: 0.8867 - loss: 0.2946 - val_accuracy: 0.9311 - val_loss: 0.1914
# Epoch 3/20
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 0s 802ms/step - accuracy: 0.9165 - loss: 0.2190
# Epoch 3: val_accuracy improved from 0.93106 to 0.93825, saving model to best_densenet201_cancer_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 2003s 1s/step - accuracy: 0.9165 - loss: 0.2190 - val_accuracy: 0.9383 - val_loss: 0.1625
# Epoch 4/20
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 0s 802ms/step - accuracy: 0.9317 - loss: 0.1818
# Epoch 4: val_accuracy improved from 0.93825 to 0.95069, saving model to best_densenet201_cancer_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 2003s 1s/step - accuracy: 0.9317 - loss: 0.1818 - val_accuracy: 0.9507 - val_loss: 0.1360
# Epoch 5/20
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 0s 800ms/step - accuracy: 0.9450 - loss: 0.1499
# Epoch 5: val_accuracy improved from 0.95069 to 0.95681, saving model to best_densenet201_cancer_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 1997s 998ms/step - accuracy: 0.9450 - loss: 0.1499 - val_accuracy: 0.9568 - val_loss: 0.1190
# Epoch 6/20
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 0s 795ms/step - accuracy: 0.9518 - loss: 0.1328
# Epoch 6: val_accuracy improved from 0.95681 to 0.95900, saving model to best_densenet201_cancer_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 1988s 994ms/step - accuracy: 0.9518 - loss: 0.1328 - val_accuracy: 0.9590 - val_loss: 0.1087
# Epoch 7/20
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 0s 801ms/step - accuracy: 0.9591 - loss: 0.1155
# Epoch 7: val_accuracy improved from 0.95900 to 0.96481, saving model to best_densenet201_cancer_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 2052s 1s/step - accuracy: 0.9591 - loss: 0.1155 - val_accuracy: 0.9648 - val_loss: 0.0979
# Epoch 8/20
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 0s 813ms/step - accuracy: 0.9622 - loss: 0.1019
# Epoch 8: val_accuracy improved from 0.96481 to 0.96550, saving model to best_densenet201_cancer_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 2026s 1s/step - accuracy: 0.9622 - loss: 0.1019 - val_accuracy: 0.9655 - val_loss: 0.0930
# Epoch 9/20
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 0s 827ms/step - accuracy: 0.9659 - loss: 0.0953
# Epoch 9: val_accuracy improved from 0.96550 to 0.96825, saving model to best_densenet201_cancer_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 2057s 1s/step - accuracy: 0.9659 - loss: 0.0953 - val_accuracy: 0.9682 - val_loss: 0.0857
# Epoch 10/20
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 0s 942ms/step - accuracy: 0.9709 - loss: 0.0824
# Epoch 10: val_accuracy improved from 0.96825 to 0.97425, saving model to best_densenet201_cancer_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 2372s 1s/step - accuracy: 0.9709 - loss: 0.0824 - val_accuracy: 0.9743 - val_loss: 0.0751
# Epoch 11/20
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 0s 961ms/step - accuracy: 0.9739 - loss: 0.0754
# Epoch 11: val_accuracy improved from 0.97425 to 0.97506, saving model to best_densenet201_cancer_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 2400s 1s/step - accuracy: 0.9739 - loss: 0.0754 - val_accuracy: 0.9751 - val_loss: 0.0687
# Epoch 12/20
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9763 - loss: 0.0694
# Epoch 12: val_accuracy improved from 0.97506 to 0.97669, saving model to best_densenet201_cancer_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 2534s 1s/step - accuracy: 0.9763 - loss: 0.0694 - val_accuracy: 0.9767 - val_loss: 0.0677
# Epoch 13/20
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 0s 823ms/step - accuracy: 0.9785 - loss: 0.0636
# Epoch 13: val_accuracy improved from 0.97669 to 0.97706, saving model to best_densenet201_cancer_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 2045s 1s/step - accuracy: 0.9785 - loss: 0.0636 - val_accuracy: 0.9771 - val_loss: 0.0639
# Epoch 14/20
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 0s 800ms/step - accuracy: 0.9787 - loss: 0.0609
# Epoch 14: val_accuracy improved from 0.97706 to 0.97900, saving model to best_densenet201_cancer_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 2001s 1000ms/step - accuracy: 0.9787 - loss: 0.0609 - val_accuracy: 0.9790 - val_loss: 0.0608
# Epoch 15/20
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 0s 801ms/step - accuracy: 0.9812 - loss: 0.0563
# Epoch 15: val_accuracy did not improve from 0.97900
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 2002s 1s/step - accuracy: 0.9812 - loss: 0.0563 - val_accuracy: 0.9783 - val_loss: 0.0579
# Epoch 16/20
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 0s 802ms/step - accuracy: 0.9838 - loss: 0.0494
# Epoch 16: val_accuracy improved from 0.97900 to 0.98013, saving model to best_densenet201_cancer_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 2003s 1s/step - accuracy: 0.9838 - loss: 0.0494 - val_accuracy: 0.9801 - val_loss: 0.0563
# Epoch 17/20
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 0s 817ms/step - accuracy: 0.9847 - loss: 0.0459
# Epoch 17: val_accuracy improved from 0.98013 to 0.98131, saving model to best_densenet201_cancer_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 2045s 1s/step - accuracy: 0.9847 - loss: 0.0459 - val_accuracy: 0.9813 - val_loss: 0.0522
# Epoch 18/20
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 0s 803ms/step - accuracy: 0.9860 - loss: 0.0435
# Epoch 18: val_accuracy improved from 0.98131 to 0.98344, saving model to best_densenet201_cancer_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 2007s 1s/step - accuracy: 0.9860 - loss: 0.0435 - val_accuracy: 0.9834 - val_loss: 0.0484
# Epoch 19/20
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 0s 802ms/step - accuracy: 0.9866 - loss: 0.0407
# Epoch 19: val_accuracy did not improve from 0.98344
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 2004s 1s/step - accuracy: 0.9866 - loss: 0.0407 - val_accuracy: 0.9803 - val_loss: 0.0525
# Epoch 20/20
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 0s 800ms/step - accuracy: 0.9872 - loss: 0.0392
# Epoch 20: val_accuracy improved from 0.98344 to 0.98506, saving model to best_densenet201_cancer_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 2001s 1000ms/step - accuracy: 0.9872 - loss: 0.0392 - val_accuracy: 0.9851 - val_loss: 0.0442
# Training completed.
# Best model saved at best_densenet201_cancer_model.h5
# Loading best model for evaluation...
# Predicting classes on validation data...
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 403s 798ms/step
# C:\Users\kashi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\trainers\epoch_iterator.py:116: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# Classification Report:
#                   precision    recall  f1-score   support
#
#       all_benign       1.00      1.00      1.00      1000
#        all_early       1.00      1.00      1.00      1000
#          all_pre       1.00      1.00      1.00      1000
#          all_pro       1.00      1.00      1.00      1000
#    breast_benign       0.98      0.99      0.99      1000
# breast_malignant       0.99      0.98      0.98      1000
#        colon_aca       1.00      1.00      1.00      1000
#        colon_bnt       1.00      1.00      1.00      1000
#         lung_aca       0.99      0.99      0.99      1000
#         lung_bnt       1.00      1.00      1.00      1000
#         lung_scc       0.99      0.99      0.99      1000
#        lymph_cll       0.97      0.98      0.98      1000
#         lymph_fl       0.99      0.98      0.98      1000
#        lymph_mcl       0.98      0.97      0.97      1000
#      oral_normal       0.94      0.94      0.94      1000
#         oral_scc       0.94      0.94      0.94      1000
#
#         accuracy                           0.99     16000
#        macro avg       0.99      0.99      0.99     16000
#     weighted avg       0.99      0.99      0.99     16000
