# %%
import os
data = "data"
categories = os.listdir(data)
print("Categories found:", categories)
# Out:
# Categories found: ['all_benign', 'all_early', 'all_pre', 'all_pro', 'breast_benign', 'breast_malignant', 'colon_aca', 'colon_bnt', 'lung_aca', 'lung_bnt', 'lung_scc', 'lymph_cll', 'lymph_fl', 'lymph_mcl', 'oral_normal', 'oral_scc']

# %%
image_counts = {}
total_images = 0

for subclass in os.listdir(data):
    subclass_path = os.path.join(data, subclass)
    if os.path.isdir(subclass_path):
        num_images = len([
            f for f in os.listdir(subclass_path)
            if os.path.isfile(os.path.join(subclass_path, f))
        ])
        image_counts[subclass] = num_images
        total_images += num_images

print("Image counts in ALL subclasses:")
for subclass, count in image_counts.items():
    print(f"{subclass}: {count}")
print(f"\nTotal images in ALL: {total_images}")
# Out:
# Image counts in ALL subclasses:
# all_benign: 5000
# all_early: 5000
# all_pre: 5000
# all_pro: 5000
# breast_benign: 5000
# breast_malignant: 5000
# colon_aca: 5000
# colon_bnt: 5000
# lung_aca: 5000
# lung_bnt: 5000
# lung_scc: 5000
# lymph_cll: 5000
# lymph_fl: 5000
# lymph_mcl: 5000
# oral_normal: 5001
# oral_scc: 5001
#
# Total images in ALL: 80002

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# PARAMETERS
train_dir = data  # Folder with 5 subfolders (cancer types)
img_height, img_width = 224, 224    # VGG16 input size
batch_size = 32
num_classes = 16
epochs = 10

# -------------------------------
# LOAD DATA - NO AUGMENTATION, ONLY RESIZE AND RESCALE
# -------------------------------
print("Loading training data without augmentation (only rescaling)...")

datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2  # 20% validation split
)

train_generator = datagen.flow_from_directory(
    train_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical',
    subset='training',
    shuffle=True
)

validation_generator = datagen.flow_from_directory(
    train_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation',
    shuffle=False
)

# -------------------------------
# LOAD VGG16 BASE MODEL AND FREEZE LAYERS
# -------------------------------
print("Loading VGG16 pre-trained base model...")
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(img_height, img_width, 3))

for layer in base_model.layers:
    layer.trainable = False
print(f"Frozen {len(base_model.layers)} layers of VGG16 base.")

# -------------------------------
# ADD CLASSIFIER ON TOP
# -------------------------------
x = base_model.output
x = Flatten()(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.5)(x)
predictions = Dense(num_classes, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=predictions)

# -------------------------------
# COMPILE MODEL
# -------------------------------
print("Compiling model...")
model.compile(
    optimizer=Adam(learning_rate=0.0001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# -------------------------------
# TRAIN MODEL WITH CHECKPOINT
# -------------------------------
checkpoint_filepath = 'best_vgg16_cancer_model.h5'
checkpoint = tf.keras.callbacks.ModelCheckpoint(
    checkpoint_filepath, monitor='val_accuracy', save_best_only=True, verbose=1
)

print(f"Training for {epochs} epochs...")
history = model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=epochs,
    callbacks=[checkpoint]
)

print("Training completed.")
print(f"Best model saved at {checkpoint_filepath}")

# -------------------------------
# LOAD BEST MODEL FROM CHECKPOINT
# -------------------------------
print("Loading best model for evaluation...")
model.load_weights(checkpoint_filepath)

# -------------------------------
# PREDICTIONS AND CONFUSION MATRIX
# -------------------------------
print("Predicting classes on validation data...")
val_steps = validation_generator.samples // validation_generator.batch_size + 1

# Predict probabilities for validation data
y_pred_probs = model.predict(validation_generator, steps=val_steps)
y_pred = np.argmax(y_pred_probs, axis=1)

# True labels
y_true = validation_generator.classes

# Labels for confusion matrix and classification report
class_labels = list(validation_generator.class_indices.keys())

# Compute confusion matrix
cm = confusion_matrix(y_true, y_pred)

# Display confusion matrix as heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()

# Print classification report
print("Classification Report:")
print(classification_report(y_true, y_pred, target_names=class_labels))
# Out:
# Loading training data without augmentation (only rescaling)...
# Found 64002 images belonging to 16 classes.
# Found 16000 images belonging to 16 classes.
# Loading VGG16 pre-trained base model...
# Frozen 19 layers of VGG16 base.
# Compiling model...
# Training for 10 epochs...
# c:\Users\revna\Desktop\Colab Projects\Cancer_Classification\can_venv\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6899 - loss: 0.8723
# Epoch 1: val_accuracy improved from -inf to 0.87762, saving model to best_vgg16_cancer_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 6498s 3s/step - accuracy: 0.6899 - loss: 0.8722 - val_accuracy: 0.8776 - val_loss: 0.3057
# Epoch 2/10
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8649 - loss: 0.3368
# Epoch 2: val_accuracy improved from 0.87762 to 0.90613, saving model to best_vgg16_cancer_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 6446s 3s/step - accuracy: 0.8649 - loss: 0.3368 - val_accuracy: 0.9061 - val_loss: 0.2337
# Epoch 3/10
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8949 - loss: 0.2584
# Epoch 3: val_accuracy improved from 0.90613 to 0.91206, saving model to best_vgg16_cancer_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 6382s 3s/step - accuracy: 0.8949 - loss: 0.2584 - val_accuracy: 0.9121 - val_loss: 0.2211
# Epoch 4/10
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9141 - loss: 0.2162
# Epoch 4: val_accuracy improved from 0.91206 to 0.93037, saving model to best_vgg16_cancer_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 6475s 3s/step - accuracy: 0.9141 - loss: 0.2162 - val_accuracy: 0.9304 - val_loss: 0.1797
# Epoch 5/10
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9291 - loss: 0.1822
# Epoch 5: val_accuracy did not improve from 0.93037
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 6464s 3s/step - accuracy: 0.9291 - loss: 0.1822 - val_accuracy: 0.9281 - val_loss: 0.1809
# Epoch 6/10
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9349 - loss: 0.1651
# Epoch 6: val_accuracy improved from 0.93037 to 0.94063, saving model to best_vgg16_cancer_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 6454s 3s/step - accuracy: 0.9349 - loss: 0.1651 - val_accuracy: 0.9406 - val_loss: 0.1612
# Epoch 7/10
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9477 - loss: 0.1390
# Epoch 7: val_accuracy improved from 0.94063 to 0.94706, saving model to best_vgg16_cancer_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 6467s 3s/step - accuracy: 0.9477 - loss: 0.1390 - val_accuracy: 0.9471 - val_loss: 0.1413
# Epoch 8/10
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9529 - loss: 0.1254
# Epoch 8: val_accuracy improved from 0.94706 to 0.95156, saving model to best_vgg16_cancer_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 6463s 3s/step - accuracy: 0.9529 - loss: 0.1254 - val_accuracy: 0.9516 - val_loss: 0.1286
# Epoch 9/10
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9573 - loss: 0.1138
# Epoch 9: val_accuracy improved from 0.95156 to 0.95594, saving model to best_vgg16_cancer_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 6467s 3s/step - accuracy: 0.9573 - loss: 0.1138 - val_accuracy: 0.9559 - val_loss: 0.1202
# Epoch 10/10
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9624 - loss: 0.1014
# Epoch 10: val_accuracy did not improve from 0.95594
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 6469s 3s/step - accuracy: 0.9624 - loss: 0.1014 - val_accuracy: 0.9546 - val_loss: 0.1235
# Training completed.
# Best model saved at best_vgg16_cancer_model.h5
# Loading best model for evaluation...
# Predicting classes on validation data...
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1283s 3s/step
# c:\Users\revna\Desktop\Colab Projects\Cancer_Classification\can_venv\Lib\site-packages\keras\src\trainers\epoch_iterator.py:116: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# Classification Report:
#                   precision    recall  f1-score   support
#
#       all_benign       1.00      1.00      1.00      1000
#        all_early       0.99      1.00      1.00      1000
#          all_pre       1.00      1.00      1.00      1000
#          all_pro       1.00      1.00      1.00      1000
#    breast_benign       0.98      0.96      0.97      1000
# breast_malignant       0.97      0.95      0.96      1000
#        colon_aca       0.98      0.99      0.98      1000
#        colon_bnt       1.00      0.99      1.00      1000
#         lung_aca       0.98      0.98      0.98      1000
#         lung_bnt       0.99      1.00      1.00      1000
#         lung_scc       0.98      0.98      0.98      1000
#        lymph_cll       0.87      0.94      0.90      1000
#         lymph_fl       0.89      0.90      0.90      1000
#        lymph_mcl       0.91      0.82      0.86      1000
#      oral_normal       0.88      0.90      0.89      1000
#         oral_scc       0.90      0.88      0.89      1000
#
#         accuracy                           0.96     16000
#        macro avg       0.96      0.96      0.96     16000
#     weighted avg       0.96      0.96      0.96     16000
