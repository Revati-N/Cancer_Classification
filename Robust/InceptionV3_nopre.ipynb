# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# PARAMETERS
train_dir = r'C:\Users\kashi\Desktop\LY Project\Multi Cancer\Robust\Robust_Data'  # Dataset path
img_height, img_width = 299, 299  # InceptionV3 input size
batch_size = 32
num_classes = 16  # Update if number of classes differs
epochs = 10

# LOAD DATA - RESCALE AND SPLIT
print("Loading training data without augmentation (only rescaling)...")

datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2  # 20% validation split
)

train_generator = datagen.flow_from_directory(
    train_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical',
    subset='training',
    shuffle=True
)

validation_generator = datagen.flow_from_directory(
    train_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation',
    shuffle=False
)

# LOAD InceptionV3 BASE MODEL AND FREEZE LAYERS
print("Loading InceptionV3 pre-trained base model...")
base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=(img_height, img_width, 3))

for layer in base_model.layers:
    layer.trainable = False
print(f"Frozen {len(base_model.layers)} layers of InceptionV3 base.")

# ADD CUSTOM CLASSIFIER ON TOP
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.5)(x)
predictions = Dense(num_classes, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=predictions)

# COMPILE MODEL
print("Compiling model...")
model.compile(
    optimizer=Adam(learning_rate=0.0001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# TRAIN MODEL WITH CHECKPOINT
checkpoint_filepath = 'best_inceptionv3_cancer_model.h5'
checkpoint = tf.keras.callbacks.ModelCheckpoint(
    checkpoint_filepath, monitor='val_accuracy', save_best_only=True, verbose=1
)

print(f"Training for {epochs} epochs...")
history = model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=epochs,
    callbacks=[checkpoint]
)

print("Training completed.")
print(f"Best model saved at {checkpoint_filepath}")

# LOAD BEST MODEL FROM CHECKPOINT
print("Loading best model for evaluation...")
model.load_weights(checkpoint_filepath)

# PREDICTIONS AND CONFUSION MATRIX
print("Predicting classes on validation data...")
val_steps = validation_generator.samples // validation_generator.batch_size + 1

y_pred_probs = model.predict(validation_generator, steps=val_steps)
y_pred = np.argmax(y_pred_probs, axis=1)

y_true = validation_generator.classes
class_labels = list(validation_generator.class_indices.keys())

cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()

print("Classification Report:")
print(classification_report(y_true, y_pred, target_names=class_labels))
# Out:
# Loading training data without augmentation (only rescaling)...
# Found 64002 images belonging to 16 classes.
# Found 16000 images belonging to 16 classes.
# Loading InceptionV3 pre-trained base model...
# Frozen 311 layers of InceptionV3 base.
# Compiling model...
# Training for 10 epochs...
# Epoch 1/10
# C:\Users\kashi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 0s 567ms/step - accuracy: 0.6477 - loss: 1.0020
# Epoch 1: val_accuracy improved from -inf to 0.88081, saving model to best_inceptionv3_cancer_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 1426s 711ms/step - accuracy: 0.6478 - loss: 1.0018 - val_accuracy: 0.8808 - val_loss: 0.3186
# Epoch 2/10
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 0s 664ms/step - accuracy: 0.8561 - loss: 0.3694
# Epoch 2: val_accuracy improved from 0.88081 to 0.90137, saving model to best_inceptionv3_cancer_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 1703s 851ms/step - accuracy: 0.8561 - loss: 0.3694 - val_accuracy: 0.9014 - val_loss: 0.2532
# Epoch 3/10
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 0s 747ms/step - accuracy: 0.8881 - loss: 0.2877
# Epoch 3: val_accuracy improved from 0.90137 to 0.91325, saving model to best_inceptionv3_cancer_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 1866s 933ms/step - accuracy: 0.8881 - loss: 0.2877 - val_accuracy: 0.9133 - val_loss: 0.2224
# Epoch 4/10
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 0s 741ms/step - accuracy: 0.9060 - loss: 0.2460
# Epoch 4: val_accuracy improved from 0.91325 to 0.92844, saving model to best_inceptionv3_cancer_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 1857s 928ms/step - accuracy: 0.9060 - loss: 0.2460 - val_accuracy: 0.9284 - val_loss: 0.1892
# Epoch 5/10
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 0s 764ms/step - accuracy: 0.9188 - loss: 0.2127
# Epoch 5: val_accuracy improved from 0.92844 to 0.93512, saving model to best_inceptionv3_cancer_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 1891s 945ms/step - accuracy: 0.9188 - loss: 0.2127 - val_accuracy: 0.9351 - val_loss: 0.1721
# Epoch 6/10
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 0s 572ms/step - accuracy: 0.9243 - loss: 0.1963
# Epoch 6: val_accuracy improved from 0.93512 to 0.94106, saving model to best_inceptionv3_cancer_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 1427s 713ms/step - accuracy: 0.9243 - loss: 0.1963 - val_accuracy: 0.9411 - val_loss: 0.1612
# Epoch 7/10
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 0s 565ms/step - accuracy: 0.9331 - loss: 0.1746
# Epoch 7: val_accuracy improved from 0.94106 to 0.94594, saving model to best_inceptionv3_cancer_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 1413s 706ms/step - accuracy: 0.9331 - loss: 0.1746 - val_accuracy: 0.9459 - val_loss: 0.1495
# Epoch 8/10
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 0s 602ms/step - accuracy: 0.9375 - loss: 0.1646
# Epoch 8: val_accuracy improved from 0.94594 to 0.94600, saving model to best_inceptionv3_cancer_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 1519s 759ms/step - accuracy: 0.9375 - loss: 0.1646 - val_accuracy: 0.9460 - val_loss: 0.1421
# Epoch 9/10
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 0s 571ms/step - accuracy: 0.9449 - loss: 0.1494
# Epoch 9: val_accuracy improved from 0.94600 to 0.95194, saving model to best_inceptionv3_cancer_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 1424s 712ms/step - accuracy: 0.9449 - loss: 0.1494 - val_accuracy: 0.9519 - val_loss: 0.1337
# Epoch 10/10
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 0s 562ms/step - accuracy: 0.9470 - loss: 0.1364
# Epoch 10: val_accuracy did not improve from 0.95194
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 1406s 703ms/step - accuracy: 0.9470 - loss: 0.1364 - val_accuracy: 0.9519 - val_loss: 0.1308
# Training completed.
# Best model saved at best_inceptionv3_cancer_model.h5
# Loading best model for evaluation...
# Predicting classes on validation data...
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 282s 561ms/step
# C:\Users\kashi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\trainers\epoch_iterator.py:116: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# Classification Report:
#                   precision    recall  f1-score   support
#
#       all_benign       0.99      0.99      0.99      1000
#        all_early       0.99      0.99      0.99      1000
#          all_pre       0.99      0.99      0.99      1000
#          all_pro       0.99      1.00      1.00      1000
#    breast_benign       0.95      0.98      0.96      1000
# breast_malignant       0.98      0.95      0.97      1000
#        colon_aca       1.00      0.99      1.00      1000
#        colon_bnt       1.00      1.00      1.00      1000
#         lung_aca       0.96      0.98      0.97      1000
#         lung_bnt       1.00      1.00      1.00      1000
#         lung_scc       0.98      0.96      0.97      1000
#        lymph_cll       0.95      0.85      0.89      1000
#         lymph_fl       0.87      0.92      0.89      1000
#        lymph_mcl       0.86      0.90      0.88      1000
#      oral_normal       0.88      0.86      0.87      1000
#         oral_scc       0.86      0.87      0.86      1000
#
#         accuracy                           0.95     16000
#        macro avg       0.95      0.95      0.95     16000
#     weighted avg       0.95      0.95      0.95     16000
