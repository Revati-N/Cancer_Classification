# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# PARAMETERS
train_dir = r'C:\Users\kashi\Desktop\LY Project\Multi Cancer\Robust\Robust_Data'  # Dataset path
img_height, img_width = 299, 299  # InceptionV3 input size
batch_size = 32
num_classes = 16  # Update if number of classes differs
epochs = 20

# LOAD DATA - RESCALE AND SPLIT
print("Loading training data without augmentation (only rescaling)...")

datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2  # 20% validation split
)

train_generator = datagen.flow_from_directory(
    train_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical',
    subset='training',
    shuffle=True
)

validation_generator = datagen.flow_from_directory(
    train_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation',
    shuffle=False
)

# LOAD InceptionV3 BASE MODEL AND FREEZE LAYERS
print("Loading InceptionV3 pre-trained base model...")
base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=(img_height, img_width, 3))

for layer in base_model.layers:
    layer.trainable = False
print(f"Frozen {len(base_model.layers)} layers of InceptionV3 base.")

# ADD CUSTOM CLASSIFIER ON TOP
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.5)(x)
predictions = Dense(num_classes, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=predictions)

# COMPILE MODEL
print("Compiling model...")
model.compile(
    optimizer=Adam(learning_rate=0.0001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# TRAIN MODEL WITH CHECKPOINT
checkpoint_filepath = 'best_inceptionv3_cancer_model.h5'
checkpoint = tf.keras.callbacks.ModelCheckpoint(
    checkpoint_filepath, monitor='val_accuracy', save_best_only=True, verbose=1
)

print(f"Training for {epochs} epochs...")
history = model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=epochs,
    callbacks=[checkpoint]
)

print("Training completed.")
print(f"Best model saved at {checkpoint_filepath}")

# LOAD BEST MODEL FROM CHECKPOINT
print("Loading best model for evaluation...")
model.load_weights(checkpoint_filepath)

# PREDICTIONS AND CONFUSION MATRIX
print("Predicting classes on validation data...")
val_steps = validation_generator.samples // validation_generator.batch_size + 1

y_pred_probs = model.predict(validation_generator, steps=val_steps)
y_pred = np.argmax(y_pred_probs, axis=1)

y_true = validation_generator.classes
class_labels = list(validation_generator.class_indices.keys())

cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()

print("Classification Report:")
print(classification_report(y_true, y_pred, target_names=class_labels))
# Out:
# Loading training data without augmentation (only rescaling)...
# Found 64002 images belonging to 16 classes.
# Found 16000 images belonging to 16 classes.
# Loading InceptionV3 pre-trained base model...
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 ━━━━━━━━━━━━━━━━━━━━ 9s 0us/step
# Frozen 311 layers of InceptionV3 base.
# Compiling model...
# Training for 20 epochs...
# C:\Users\kashi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/20
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 0s 657ms/step - accuracy: 0.6607 - loss: 0.9786
# Epoch 1: val_accuracy improved from -inf to 0.88019, saving model to best_inceptionv3_cancer_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 1652s 824ms/step - accuracy: 0.6608 - loss: 0.9785 - val_accuracy: 0.8802 - val_loss: 0.3178
# Epoch 2/20
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 0s 584ms/step - accuracy: 0.8596 - loss: 0.3613
# Epoch 2: val_accuracy improved from 0.88019 to 0.90381, saving model to best_inceptionv3_cancer_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 1486s 743ms/step - accuracy: 0.8596 - loss: 0.3613 - val_accuracy: 0.9038 - val_loss: 0.2515
# Epoch 3/20
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 0s 559ms/step - accuracy: 0.8892 - loss: 0.2839
# Epoch 3: val_accuracy improved from 0.90381 to 0.91444, saving model to best_inceptionv3_cancer_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 1395s 697ms/step - accuracy: 0.8892 - loss: 0.2839 - val_accuracy: 0.9144 - val_loss: 0.2163
# Epoch 4/20
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 0s 616ms/step - accuracy: 0.9057 - loss: 0.2458
# Epoch 4: val_accuracy improved from 0.91444 to 0.92500, saving model to best_inceptionv3_cancer_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 1560s 780ms/step - accuracy: 0.9057 - loss: 0.2458 - val_accuracy: 0.9250 - val_loss: 0.1934
# Epoch 5/20
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 0s 618ms/step - accuracy: 0.9185 - loss: 0.2120
# Epoch 5: val_accuracy improved from 0.92500 to 0.93569, saving model to best_inceptionv3_cancer_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 1517s 758ms/step - accuracy: 0.9185 - loss: 0.2120 - val_accuracy: 0.9357 - val_loss: 0.1704
# Epoch 6/20
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 0s 576ms/step - accuracy: 0.9266 - loss: 0.1926
# Epoch 6: val_accuracy improved from 0.93569 to 0.94100, saving model to best_inceptionv3_cancer_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 1439s 719ms/step - accuracy: 0.9266 - loss: 0.1926 - val_accuracy: 0.9410 - val_loss: 0.1578
# Epoch 7/20
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 0s 580ms/step - accuracy: 0.9348 - loss: 0.1737
# Epoch 7: val_accuracy improved from 0.94100 to 0.94463, saving model to best_inceptionv3_cancer_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 1450s 725ms/step - accuracy: 0.9348 - loss: 0.1737 - val_accuracy: 0.9446 - val_loss: 0.1503
# Epoch 8/20
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 0s 580ms/step - accuracy: 0.9398 - loss: 0.1597
# Epoch 8: val_accuracy did not improve from 0.94463
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 1449s 724ms/step - accuracy: 0.9398 - loss: 0.1597 - val_accuracy: 0.9434 - val_loss: 0.1470
# Epoch 9/20
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 0s 579ms/step - accuracy: 0.9445 - loss: 0.1472
# Epoch 9: val_accuracy improved from 0.94463 to 0.95131, saving model to best_inceptionv3_cancer_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 1443s 721ms/step - accuracy: 0.9445 - loss: 0.1472 - val_accuracy: 0.9513 - val_loss: 0.1311
# Epoch 10/20
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 0s 573ms/step - accuracy: 0.9486 - loss: 0.1388
# Epoch 10: val_accuracy did not improve from 0.95131
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 1431s 715ms/step - accuracy: 0.9486 - loss: 0.1388 - val_accuracy: 0.9501 - val_loss: 0.1326
# Epoch 11/20
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 0s 570ms/step - accuracy: 0.9518 - loss: 0.1291
# Epoch 11: val_accuracy improved from 0.95131 to 0.95381, saving model to best_inceptionv3_cancer_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 1425s 712ms/step - accuracy: 0.9518 - loss: 0.1291 - val_accuracy: 0.9538 - val_loss: 0.1223
# Epoch 12/20
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 0s 577ms/step - accuracy: 0.9555 - loss: 0.1240
# Epoch 12: val_accuracy improved from 0.95381 to 0.95562, saving model to best_inceptionv3_cancer_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 1442s 721ms/step - accuracy: 0.9555 - loss: 0.1240 - val_accuracy: 0.9556 - val_loss: 0.1166
# Epoch 13/20
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 0s 572ms/step - accuracy: 0.9569 - loss: 0.1147
# Epoch 13: val_accuracy improved from 0.95562 to 0.95806, saving model to best_inceptionv3_cancer_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 1428s 713ms/step - accuracy: 0.9569 - loss: 0.1147 - val_accuracy: 0.9581 - val_loss: 0.1134
# Epoch 14/20
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 0s 570ms/step - accuracy: 0.9596 - loss: 0.1101
# Epoch 14: val_accuracy did not improve from 0.95806
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 1425s 712ms/step - accuracy: 0.9596 - loss: 0.1101 - val_accuracy: 0.9537 - val_loss: 0.1198
# Epoch 15/20
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 0s 572ms/step - accuracy: 0.9623 - loss: 0.1014
# Epoch 15: val_accuracy improved from 0.95806 to 0.96213, saving model to best_inceptionv3_cancer_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 1430s 715ms/step - accuracy: 0.9623 - loss: 0.1014 - val_accuracy: 0.9621 - val_loss: 0.1035
# Epoch 16/20
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 0s 571ms/step - accuracy: 0.9659 - loss: 0.0957
# Epoch 16: val_accuracy improved from 0.96213 to 0.96456, saving model to best_inceptionv3_cancer_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 1426s 713ms/step - accuracy: 0.9659 - loss: 0.0957 - val_accuracy: 0.9646 - val_loss: 0.0981
# Epoch 17/20
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 0s 569ms/step - accuracy: 0.9644 - loss: 0.0943
# Epoch 17: val_accuracy improved from 0.96456 to 0.96600, saving model to best_inceptionv3_cancer_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 1422s 711ms/step - accuracy: 0.9644 - loss: 0.0943 - val_accuracy: 0.9660 - val_loss: 0.0939
# Epoch 18/20
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 0s 568ms/step - accuracy: 0.9677 - loss: 0.0856
# Epoch 18: val_accuracy did not improve from 0.96600
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 1419s 709ms/step - accuracy: 0.9677 - loss: 0.0856 - val_accuracy: 0.9647 - val_loss: 0.0955
# Epoch 19/20
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 0s 570ms/step - accuracy: 0.9696 - loss: 0.0822
# Epoch 19: val_accuracy improved from 0.96600 to 0.96619, saving model to best_inceptionv3_cancer_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 1426s 712ms/step - accuracy: 0.9696 - loss: 0.0822 - val_accuracy: 0.9662 - val_loss: 0.0912
# Epoch 20/20
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 0s 571ms/step - accuracy: 0.9715 - loss: 0.0787
# Epoch 20: val_accuracy did not improve from 0.96619
# 2001/2001 ━━━━━━━━━━━━━━━━━━━━ 1427s 713ms/step - accuracy: 0.9715 - loss: 0.0787 - val_accuracy: 0.9655 - val_loss: 0.0900
# Training completed.
# Best model saved at best_inceptionv3_cancer_model.h5
# Loading best model for evaluation...
# Predicting classes on validation data...
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 287s 570ms/step
# C:\Users\kashi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\trainers\epoch_iterator.py:116: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# Classification Report:
#                   precision    recall  f1-score   support
#
#       all_benign       0.99      1.00      0.99      1000
#        all_early       1.00      0.98      0.99      1000
#          all_pre       0.99      1.00      0.99      1000
#          all_pro       1.00      0.99      1.00      1000
#    breast_benign       0.97      0.97      0.97      1000
# breast_malignant       0.98      0.97      0.97      1000
#        colon_aca       1.00      1.00      1.00      1000
#        colon_bnt       1.00      1.00      1.00      1000
#         lung_aca       0.99      0.98      0.98      1000
#         lung_bnt       1.00      1.00      1.00      1000
#         lung_scc       0.99      0.99      0.99      1000
#        lymph_cll       0.95      0.92      0.94      1000
#         lymph_fl       0.89      0.96      0.92      1000
#        lymph_mcl       0.94      0.89      0.92      1000
#      oral_normal       0.88      0.92      0.90      1000
#         oral_scc       0.91      0.88      0.89      1000
#
#         accuracy                           0.97     16000
#        macro avg       0.97      0.97      0.97     16000
#     weighted avg       0.97      0.97      0.97     16000
